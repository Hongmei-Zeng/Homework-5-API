# %% [markdown]
# # WeatherPy

# %%
from citipy import citipy
import numpy as np
import requests
from api_keys import api_key
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generate a Cities List

# %% [markdown]
# ### Random a Cities List

# %%
# Create a set of random latitudes and Longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Identify nearest city for each combination of lat & lng
random_cities = []
for lat, lng in zip(lats, lngs):
    random_city = citipy.nearest_city(lat, lng).city_name
    if random_city not in random_cities:
        random_cities.append(random_city)

len(random_cities)
# Out:
# 654

# %% [markdown]
# ### Sample a Cities List which exist in OpenWeatherMap System

# %%
def get_weather(city, api_key):
    url = 'http://api.openweathermap.org/data/2.5/weather?'
    r = requests.get(url, params={
        'appid': api_key,
        'q': city})
    if r.status_code == 200:
        return r.json()
    else:
        return None

# %%
sample_cities = []
for city in random_cities:
    sample_city = get_weather(city, api_key)
    if sample_city:
        sample_cities.append(sample_city)
        
# To see if the city amount meets the requirements (500+)
len(sample_cities)
# Out:
# 590

# %%
sample_cities
# Out:
# [{'coord': {'lon': 24.72, 'lat': 56.75},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 272.38,
#    'feels_like': 266.62,
#    'temp_min': 272.04,
#    'temp_max': 273.15,
#    'pressure': 1020,
#    'humidity': 95},
#   'visibility': 6000,
#   'wind': {'speed': 5.1, 'deg': 190},
#   'clouds': {'all': 90},
#   'dt': 1578279190,
#   'sys': {'type': 1,
#    'id': 1876,
#    'country': 'LV',
#    'sunrise': 1578293726,
#    'sunset': 1578319048},
#   'timezone': 7200,
#   'id': 458892,
#   'name': 'Kegums',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'feels_like': 294.1,
#    'temp_min': 293.15,
#    'temp_max': 293.15,
#    'pressure': 1019,
#    'humidity': 88},
#   'visibility': 3000,
#   'wind': {'speed': 2.6, 'deg': 70},
#   'clouds': {'all': 75},
#   'dt': 1578278791,
#   'sys': {'type': 1,
#    'id': 9229,
#    'country': 'IN',
#    'sunrise': 1578274186,
#    'sunset': 1578314692},
#   'timezone': 19800,
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': 143.24, 'lat': 59.36},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 258.36,
#    'feels_like': 252.01,
#    'temp_min': 258.36,
#    'temp_max': 258.36,
#    'pressure': 1024,
#    'humidity': 79,
#    'sea_level': 1024,
#    'grnd_level': 1019},
#   'wind': {'speed': 4.08, 'deg': 338},
#   'clouds': {'all': 0},
#   'dt': 1578278820,
#   'sys': {'country': 'RU', 'sunrise': 1578266468, 'sunset': 1578289399},
#   'timezone': 36000,
#   'id': 2122605,
#   'name': 'Okhotsk',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 302.66,
#    'feels_like': 296.71,
#    'temp_min': 301.48,
#    'temp_max': 305.37,
#    'pressure': 1005,
#    'humidity': 12},
#   'wind': {'speed': 5.11, 'deg': 259},
#   'clouds': {'all': 23},
#   'dt': 1578278766,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1578258901,
#    'sunset': 1578310358},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -0.6, 'lat': 45.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 273.42,
#    'feels_like': 270.28,
#    'temp_min': 270.93,
#    'temp_max': 275.15,
#    'pressure': 1028,
#    'humidity': 93},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1578278738,
#   'sys': {'type': 1,
#    'id': 6452,
#    'country': 'FR',
#    'sunrise': 1578296551,
#    'sunset': 1578328381},
#   'timezone': 3600,
#   'id': 3026644,
#   'name': 'Souillac',
#   'cod': 200},
#  {'coord': {'lon': 48.53, 'lat': 5.35},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 298.62,
#    'feels_like': 299.78,
#    'temp_min': 298.62,
#    'temp_max': 298.62,
#    'pressure': 1011,
#    'humidity': 83,
#    'sea_level': 1011,
#    'grnd_level': 1004},
#   'wind': {'speed': 5.34, 'deg': 53},
#   'clouds': {'all': 51},
#   'dt': 1578278744,
#   'sys': {'country': 'SO', 'sunrise': 1578279390, 'sunset': 1578321952},
#   'timezone': 10800,
#   'id': 57000,
#   'name': 'Hobyo',
#   'cod': 200},
#  {'coord': {'lon': -52.96, 'lat': 5.38},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'model',
#   'main': {'temp': 299.43,
#    'feels_like': 300.93,
#    'temp_min': 299.43,
#    'temp_max': 299.43,
#    'pressure': 1013,
#    'humidity': 78,
#    'sea_level': 1013,
#    'grnd_level': 1012},
#   'wind': {'speed': 4.67, 'deg': 59},
#   'clouds': {'all': 24},
#   'dt': 1578279190,
#   'sys': {'country': 'GF', 'sunrise': 1578217333, 'sunset': 1578259886},
#   'timezone': -10800,
#   'id': 3380290,
#   'name': 'Sinnamary',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'feels_like': 295.33,
#    'temp_min': 293.15,
#    'temp_max': 293.15,
#    'pressure': 1011,
#    'humidity': 93},
#   'wind': {'speed': 1.4, 'deg': 254},
#   'clouds': {'all': 99},
#   'dt': 1578278791,
#   'sys': {'type': 3,
#    'id': 2011314,
#    'country': 'ZA',
#    'sunrise': 1578280151,
#    'sunset': 1578331582},
#   'timezone': 7200,
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': 24.73, 'lat': -34},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 290.4,
#    'feels_like': 291.1,
#    'temp_min': 290.4,
#    'temp_max': 290.4,
#    'pressure': 1012,
#    'humidity': 87,
#    'sea_level': 1012,
#    'grnd_level': 981},
#   'wind': {'speed': 1.34, 'deg': 295},
#   'clouds': {'all': 100},
#   'dt': 1578278809,
#   'sys': {'country': 'ZA', 'sunrise': 1578280606, 'sunset': 1578332164},
#   'timezone': 7200,
#   'id': 986717,
#   'name': 'Kruisfontein',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 242.15,
#    'feels_like': 236.79,
#    'temp_min': 242.15,
#    'temp_max': 242.15,
#    'pressure': 1025,
#    'humidity': 74},
#   'visibility': 24140,
#   'wind': {'speed': 2.1, 'deg': 350},
#   'clouds': {'all': 20},
#   'dt': 1578278801,
#   'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 0, 'sunset': 0},
#   'timezone': -25200,
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': -96.47, 'lat': 15.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 299.29,
#    'feels_like': 300.81,
#    'temp_min': 298.15,
#    'temp_max': 300.15,
#    'pressure': 1016,
#    'humidity': 69},
#   'visibility': 11265,
#   'wind': {'speed': 3.1, 'deg': 270},
#   'clouds': {'all': 5},
#   'dt': 1578278832,
#   'sys': {'type': 1,
#    'id': 7096,
#    'country': 'MX',
#    'sunrise': 1578228850,
#    'sunset': 1578269261},
#   'timezone': -21600,
#   'id': 3517970,
#   'name': 'Pochutla',
#   'cod': 200},
#  {'coord': {'lon': 89.31, 'lat': 56.54},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 266.21,
#    'feels_like': 260.66,
#    'temp_min': 266.21,
#    'temp_max': 266.21,
#    'pressure': 1024,
#    'humidity': 93,
#    'sea_level': 1024,
#    'grnd_level': 996},
#   'wind': {'speed': 3.81, 'deg': 224},
#   'clouds': {'all': 98},
#   'dt': 1578279191,
#   'sys': {'country': 'RU', 'sunrise': 1578278147, 'sunset': 1578303615},
#   'timezone': 25200,
#   'id': 1488774,
#   'name': 'Tyukhtet',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 281.15,
#    'feels_like': 271.54,
#    'temp_min': 281.15,
#    'temp_max': 281.15,
#    'pressure': 996,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 11.8, 'deg': 230},
#   'clouds': {'all': 75},
#   'dt': 1578278708,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1578211517,
#    'sunset': 1578273073},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -60.23, 'lat': -38.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 289.65,
#    'feels_like': 288.88,
#    'temp_min': 289.65,
#    'temp_max': 289.65,
#    'pressure': 1001,
#    'humidity': 89,
#    'sea_level': 1001,
#    'grnd_level': 992},
#   'wind': {'speed': 3.24, 'deg': 340},
#   'clouds': {'all': 100},
#   'dt': 1578278702,
#   'sys': {'country': 'AR', 'sunrise': 1578213842, 'sunset': 1578266868},
#   'timezone': -10800,
#   'id': 3833859,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 299.76,
#    'feels_like': 301.35,
#    'temp_min': 299.76,
#    'temp_max': 299.76,
#    'pressure': 1010,
#    'humidity': 78,
#    'sea_level': 1010,
#    'grnd_level': 1009},
#   'wind': {'speed': 4.79, 'deg': 16},
#   'rain': {'3h': 1.75},
#   'clouds': {'all': 63},
#   'dt': 1578278771,
#   'sys': {'country': 'PF', 'sunrise': 1578236462, 'sunset': 1578282084},
#   'timezone': -34200,
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -7.35, 'lat': 40.36},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 274.59,
#    'feels_like': 271.74,
#    'temp_min': 273.71,
#    'temp_max': 275.37,
#    'pressure': 1032,
#    'humidity': 60},
#   'wind': {'speed': 0.28, 'deg': 259},
#   'clouds': {'all': 0},
#   'dt': 1578278821,
#   'sys': {'type': 3,
#    'id': 2031666,
#    'country': 'PT',
#    'sunrise': 1578297146,
#    'sunset': 1578331027},
#   'timezone': 0,
#   'id': 8010472,
#   'name': 'Belmonte',
#   'cod': 200},
#  {'coord': {'lon': 113.57, 'lat': 56.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 254.55,
#    'feels_like': 250.46,
#    'temp_min': 254.55,
#    'temp_max': 254.55,
#    'pressure': 1035,
#    'humidity': 91,
#    'sea_level': 1035,
#    'grnd_level': 863},
#   'wind': {'speed': 0.73, 'deg': 282},
#   'clouds': {'all': 8},
#   'dt': 1578279192,
#   'sys': {'country': 'RU', 'sunrise': 1578272181, 'sunset': 1578297932},
#   'timezone': 28800,
#   'id': 2016907,
#   'name': 'Severomuysk',
#   'cod': 200},
#  {'coord': {'lon': 76.76, 'lat': 55.31},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 261.51,
#    'feels_like': 255.58,
#    'temp_min': 261.51,
#    'temp_max': 261.51,
#    'pressure': 1023,
#    'humidity': 95,
#    'sea_level': 1023,
#    'grnd_level': 1009},
#   'wind': {'speed': 3.88, 'deg': 229},
#   'clouds': {'all': 80},
#   'dt': 1578278794,
#   'sys': {'country': 'RU', 'sunrise': 1578280689, 'sunset': 1578307098},
#   'timezone': 25200,
#   'id': 1508458,
#   'name': 'Chany',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 299.01,
#    'feels_like': 297.04,
#    'temp_min': 297.59,
#    'temp_max': 300.15,
#    'pressure': 1021,
#    'humidity': 74},
#   'visibility': 16093,
#   'wind': {'speed': 8.7, 'deg': 40},
#   'clouds': {'all': 75},
#   'dt': 1578278770,
#   'sys': {'type': 1,
#    'id': 7873,
#    'country': 'US',
#    'sunrise': 1578244644,
#    'sunset': 1578283644},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 284.15,
#    'feels_like': 282.18,
#    'temp_min': 284.15,
#    'temp_max': 284.15,
#    'pressure': 1017,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1578278789,
#   'sys': {'type': 1,
#    'id': 8512,
#    'country': 'CL',
#    'sunrise': 1578216294,
#    'sunset': 1578270912},
#   'timezone': -10800,
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': -37.64, 'lat': 65.61},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 266.84,
#    'feels_like': 251.81,
#    'temp_min': 266.84,
#    'temp_max': 266.84,
#    'pressure': 972,
#    'humidity': 90,
#    'sea_level': 972,
#    'grnd_level': 969},
#   'wind': {'speed': 17.37, 'deg': 66},
#   'snow': {'3h': 1.94},
#   'clouds': {'all': 100},
#   'dt': 1578278713,
#   'sys': {'country': 'GL', 'sunrise': 1578228205, 'sunset': 1578241659},
#   'timezone': -10800,
#   'id': 3424607,
#   'name': 'Tasiilaq',
#   'cod': 200},
#  {'coord': {'lon': 177.51, 'lat': 64.73},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 239.15,
#    'feels_like': 233.12,
#    'temp_min': 239.15,
#    'temp_max': 239.15,
#    'pressure': 1025,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 20, 'gust': 4},
#   'clouds': {'all': 0},
#   'dt': 1578278815,
#   'sys': {'type': 1,
#    'id': 8872,
#    'country': 'RU',
#    'sunrise': 1578261965,
#    'sunset': 1578277448},
#   'timezone': 43200,
#   'id': 2127202,
#   'name': 'Anadyr',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 297.59,
#    'feels_like': 300.6,
#    'temp_min': 297.59,
#    'temp_max': 297.59,
#    'pressure': 1014,
#    'humidity': 82},
#   'wind': {'speed': 1.79, 'deg': 136, 'gust': 3.58},
#   'clouds': {'all': 0},
#   'dt': 1578278705,
#   'sys': {'type': 3,
#    'id': 2005652,
#    'country': 'EC',
#    'sunrise': 1578225696,
#    'sunset': 1578269476},
#   'timezone': -21600,
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': 118.97, 'lat': -3.54},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 303.94,
#    'feels_like': 306.61,
#    'temp_min': 303.94,
#    'temp_max': 303.94,
#    'pressure': 1010,
#    'humidity': 59,
#    'sea_level': 1010,
#    'grnd_level': 995},
#   'wind': {'speed': 2.78, 'deg': 294},
#   'clouds': {'all': 75},
#   'dt': 1578279192,
#   'sys': {'country': 'ID', 'sunrise': 1578261590, 'sunset': 1578305931},
#   'timezone': 28800,
#   'id': 1636806,
#   'name': 'Majene',
#   'cod': 200},
#  {'coord': {'lon': 169.85, 'lat': -46.28},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 284.82,
#    'feels_like': 275.71,
#    'temp_min': 284.82,
#    'temp_max': 284.82,
#    'pressure': 994,
#    'humidity': 67},
#   'wind': {'speed': 11.62, 'deg': 338, 'gust': 17.88},
#   'rain': {'3h': 0.94},
#   'clouds': {'all': 100},
#   'dt': 1578278771,
#   'sys': {'type': 3,
#    'id': 2000217,
#    'country': 'NZ',
#    'sunrise': 1578243399,
#    'sunset': 1578299691},
#   'timezone': 46800,
#   'id': 2208248,
#   'name': 'Kaitangata',
#   'cod': 200},
#  {'coord': {'lon': 106.33, 'lat': 10.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 301.15,
#    'feels_like': 306,
#    'temp_min': 301.15,
#    'temp_max': 301.15,
#    'pressure': 1014,
#    'humidity': 74},
#   'visibility': 8000,
#   'wind': {'speed': 0.5},
#   'clouds': {'all': 0},
#   'dt': 1578279193,
#   'sys': {'type': 1,
#    'id': 9305,
#    'country': 'VN',
#    'sunrise': 1578266007,
#    'sunset': 1578307583},
#   'timezone': 25200,
#   'id': 1574023,
#   'name': 'Thanh Hoa',
#   'cod': 200},
#  {'coord': {'lon': 147.9, 'lat': 70.62},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'model',
#   'main': {'temp': 244.05,
#    'feels_like': 239.63,
#    'temp_min': 244.05,
#    'temp_max': 244.05,
#    'pressure': 1024,
#    'humidity': 100,
#    'sea_level': 1024,
#    'grnd_level': 1022},
#   'wind': {'speed': 0.86, 'deg': 79},
#   'clouds': {'all': 16},
#   'dt': 1578278702,
#   'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 39600,
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': -80.61, 'lat': 51.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 255.15,
#    'feels_like': 249.39,
#    'temp_min': 255.15,
#    'temp_max': 255.15,
#    'pressure': 1011,
#    'humidity': 84},
#   'visibility': 14484,
#   'wind': {'speed': 3.1, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1578279193,
#   'sys': {'type': 1,
#    'id': 860,
#    'country': 'CA',
#    'sunrise': 1578230767,
#    'sunset': 1578259728},
#   'timezone': -18000,
#   'id': 6078372,
#   'name': 'Moose Factory',
#   'cod': 200},
#  {'coord': {'lon': -73.83, 'lat': -41.87},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 284.15,
#    'feels_like': 282.18,
#    'temp_min': 284.15,
#    'temp_max': 284.15,
#    'pressure': 1017,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1578278811,
#   'sys': {'type': 1,
#    'id': 8512,
#    'country': 'CL',
#    'sunrise': 1578216435,
#    'sunset': 1578270805},
#   'timezone': -10800,
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': -45.24, 'lat': 60.14},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 271.2,
#    'feels_like': 259.2,
#    'temp_min': 271.2,
#    'temp_max': 271.2,
#    'pressure': 981,
#    'humidity': 71,
#    'sea_level': 981,
#    'grnd_level': 975},
#   'wind': {'speed': 13.2, 'deg': 287},
#   'snow': {'3h': 2.25},
#   'clouds': {'all': 100},
#   'dt': 1578278814,
#   'sys': {'country': 'GL', 'sunrise': 1578225734, 'sunset': 1578247779},
#   'timezone': -10800,
#   'id': 3421765,
#   'name': 'Nanortalik',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 283.15,
#    'feels_like': 275.23,
#    'temp_min': 283.15,
#    'temp_max': 283.15,
#    'pressure': 1000,
#    'humidity': 81},
#   'wind': {'speed': 10.28, 'deg': 234, 'gust': 19.67},
#   'rain': {'3h': 1.19},
#   'clouds': {'all': 100},
#   'dt': 1578278769,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1578243659,
#    'sunset': 1578299907},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 173.16, 'lat': -35.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 295.93,
#    'feels_like': 297.56,
#    'temp_min': 295.93,
#    'temp_max': 295.93,
#    'pressure': 1010,
#    'humidity': 72},
#   'wind': {'speed': 1.34, 'deg': 83, 'gust': 3.13},
#   'clouds': {'all': 3},
#   'dt': 1578279194,
#   'sys': {'type': 3,
#    'id': 2016422,
#    'country': 'NZ',
#    'sunrise': 1578244777,
#    'sunset': 1578296724},
#   'timezone': 46800,
#   'id': 2194098,
#   'name': 'Ahipara',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 281.04,
#    'feels_like': 275.19,
#    'temp_min': 280.93,
#    'temp_max': 281.15,
#    'pressure': 1000,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 240},
#   'clouds': {'all': 40},
#   'dt': 1578278789,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1578212758,
#    'sunset': 1578273080},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': -161.76, 'lat': 60.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 245.83,
#    'feels_like': 239.81,
#    'temp_min': 245.15,
#    'temp_max': 246.15,
#    'pressure': 1015,
#    'humidity': 68},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 20},
#   'clouds': {'all': 1},
#   'dt': 1578278665,
#   'sys': {'type': 1,
#    'id': 7640,
#    'country': 'US',
#    'sunrise': 1578254047,
#    'sunset': 1578275413},
#   'timezone': -32400,
#   'id': 5880568,
#   'name': 'Bethel',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 297.75,
#    'feels_like': 296.47,
#    'temp_min': 297.75,
#    'temp_max': 297.75,
#    'pressure': 1014,
#    'humidity': 76,
#    'sea_level': 1014,
#    'grnd_level': 1014},
#   'wind': {'speed': 7.17, 'deg': 107},
#   'clouds': {'all': 52},
#   'dt': 1578278790,
#   'sys': {'country': 'PF', 'sunrise': 1578233999, 'sunset': 1578282598},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 63.78, 'lat': 67.55},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 260.43,
#    'feels_like': 251.83,
#    'temp_min': 260.43,
#    'temp_max': 260.43,
#    'pressure': 996,
#    'humidity': 94,
#    'sea_level': 996,
#    'grnd_level': 976},
#   'wind': {'speed': 7.59, 'deg': 227},
#   'snow': {'3h': 0.13},
#   'clouds': {'all': 100},
#   'dt': 1578279195,
#   'sys': {'country': 'RU', 'sunrise': 1578293375, 'sunset': 1578300644},
#   'timezone': 10800,
#   'id': 1486910,
#   'name': 'Komsomolskiy',
#   'cod': 200},
#  {'coord': {'lon': -53.11, 'lat': 48.65},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 272.27,
#    'feels_like': 257.55,
#    'temp_min': 272.27,
#    'temp_max': 272.27,
#    'pressure': 976,
#    'humidity': 96,
#    'sea_level': 976,
#    'grnd_level': 973},
#   'wind': {'speed': 17.9, 'deg': 37},
#   'snow': {'3h': 10.06},
#   'clouds': {'all': 100},
#   'dt': 1578279195,
#   'sys': {'country': 'CA', 'sunrise': 1578223472, 'sunset': 1578253820},
#   'timezone': -12600,
#   'id': 5905393,
#   'name': 'Bonavista',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 290.41,
#    'feels_like': 288.91,
#    'temp_min': 289.82,
#    'temp_max': 291.15,
#    'pressure': 1013,
#    'humidity': 72},
#   'wind': {'speed': 3.1, 'deg': 300},
#   'clouds': {'all': 100},
#   'dt': 1578278780,
#   'sys': {'type': 1,
#    'id': 1966,
#    'country': 'ZA',
#    'sunrise': 1578281649,
#    'sunset': 1578333372},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': 90.44, 'lat': 50.38},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 253.26,
#    'feels_like': 248.18,
#    'temp_min': 253.26,
#    'temp_max': 253.26,
#    'pressure': 1040,
#    'humidity': 67,
#    'sea_level': 1040,
#    'grnd_level': 763},
#   'wind': {'speed': 1.94, 'deg': 223},
#   'clouds': {'all': 0},
#   'dt': 1578279195,
#   'sys': {'country': 'RU', 'sunrise': 1578275861, 'sunset': 1578305358},
#   'timezone': 25200,
#   'id': 1498283,
#   'name': 'Mugur-Aksy',
#   'cod': 200},
#  {'coord': {'lon': -84.28, 'lat': 15.8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 299.64,
#    'feels_like': 298.53,
#    'temp_min': 299.64,
#    'temp_max': 299.64,
#    'pressure': 1019,
#    'humidity': 81,
#    'sea_level': 1019,
#    'grnd_level': 1019},
#   'wind': {'speed': 9.04, 'deg': 289},
#   'rain': {'3h': 1.69},
#   'clouds': {'all': 37},
#   'dt': 1578278798,
#   'sys': {'country': 'HN', 'sunrise': 1578225930, 'sunset': 1578266327},
#   'timezone': -21600,
#   'id': 3614835,
#   'name': 'Barra Patuca',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 238.46,
#    'feels_like': 229.68,
#    'temp_min': 238.46,
#    'temp_max': 238.46,
#    'pressure': 984,
#    'humidity': 96,
#    'sea_level': 984,
#    'grnd_level': 984},
#   'wind': {'speed': 6.97, 'deg': 358},
#   'clouds': {'all': 94},
#   'dt': 1578278772,
#   'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'timezone': -10800,
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 245.26,
#    'feels_like': 239.59,
#    'temp_min': 245.15,
#    'temp_max': 245.37,
#    'pressure': 1010,
#    'humidity': 75},
#   'visibility': 24140,
#   'wind': {'speed': 2.6, 'deg': 360},
#   'clouds': {'all': 5},
#   'dt': 1578278775,
#   'sys': {'type': 1,
#    'id': 1007,
#    'country': 'CA',
#    'sunrise': 1578243741,
#    'sunset': 1578262969},
#   'timezone': -25200,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': -94.42, 'lat': 30.04},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 286.91,
#    'feels_like': 285.34,
#    'temp_min': 283.15,
#    'temp_max': 289.82,
#    'pressure': 1024,
#    'humidity': 82},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 170},
#   'clouds': {'all': 1},
#   'dt': 1578278806,
#   'sys': {'type': 1,
#    'id': 3476,
#    'country': 'US',
#    'sunrise': 1578230057,
#    'sunset': 1578267070},
#   'timezone': -21600,
#   'id': 4732862,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': 31.9, 'lat': 54.43},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'model',
#   'main': {'temp': 269.12,
#    'feels_like': 264.82,
#    'temp_min': 269.12,
#    'temp_max': 269.12,
#    'pressure': 1026,
#    'humidity': 91,
#    'sea_level': 1026,
#    'grnd_level': 1000},
#   'wind': {'speed': 2.38, 'deg': 299},
#   'clouds': {'all': 20},
#   'dt': 1578279196,
#   'sys': {'country': 'RU', 'sunrise': 1578291141, 'sunset': 1578318186},
#   'timezone': 10800,
#   'id': 525426,
#   'name': 'Sobolevo',
#   'cod': 200},
#  {'coord': {'lon': -97.86, 'lat': 55.74},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 258.15,
#    'feels_like': 252.21,
#    'temp_min': 258.15,
#    'temp_max': 258.15,
#    'pressure': 1006,
#    'humidity': 92},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 290},
#   'clouds': {'all': 90},
#   'dt': 1578278805,
#   'sys': {'type': 1,
#    'id': 935,
#    'country': 'CA',
#    'sunrise': 1578236373,
#    'sunset': 1578262405},
#   'timezone': -21600,
#   'id': 6165406,
#   'name': 'Thompson',
#   'cod': 200},
#  {'coord': {'lon': 13.4, 'lat': -12.58},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 298.13,
#    'feels_like': 302.46,
#    'temp_min': 298.13,
#    'temp_max': 298.13,
#    'pressure': 1010,
#    'humidity': 88,
#    'sea_level': 1010,
#    'grnd_level': 999},
#   'wind': {'speed': 1.18, 'deg': 230},
#   'clouds': {'all': 91},
#   'dt': 1578279196,
#   'sys': {'country': 'AO', 'sunrise': 1578286006, 'sunset': 1578332204},
#   'timezone': 3600,
#   'id': 3351663,
#   'name': 'Benguela',
#   'cod': 200},
#  {'coord': {'lon': 15.16, 'lat': -26.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 290.33,
#    'feels_like': 285.32,
#    'temp_min': 290.33,
#    'temp_max': 290.33,
#    'pressure': 1010,
#    'humidity': 85,
#    'sea_level': 1010,
#    'grnd_level': 1008},
#   'wind': {'speed': 9.28, 'deg': 171},
#   'clouds': {'all': 0},
#   'dt': 1578278861,
#   'sys': {'country': 'NA', 'sunrise': 1578283946, 'sunset': 1578333418},
#   'timezone': 7200,
#   'id': 3355672,
#   'name': 'Luderitz',
#   'cod': 200},
#  {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 263.73,
#    'feels_like': 258.56,
#    'temp_min': 260.93,
#    'temp_max': 266.48,
#    'pressure': 1014,
#    'humidity': 66},
#   'visibility': 14484,
#   'wind': {'speed': 2.6, 'deg': 300},
#   'clouds': {'all': 90},
#   'dt': 1578278789,
#   'sys': {'type': 1,
#    'id': 820,
#    'country': 'CA',
#    'sunrise': 1578227598,
#    'sunset': 1578259475},
#   'timezone': -18000,
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'coord': {'lon': -134.42, 'lat': 58.3},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 264.43,
#    'feels_like': 260.45,
#    'temp_min': 263.15,
#    'temp_max': 266.15,
#    'pressure': 1012,
#    'humidity': 85},
#   'visibility': 16093,
#   'wind': {'speed': 1.24, 'deg': 111},
#   'clouds': {'all': 40},
#   'dt': 1578279056,
#   'sys': {'type': 1,
#    'id': 7729,
#    'country': 'US',
#    'sunrise': 1578246207,
#    'sunset': 1578270125},
#   'timezone': -32400,
#   'id': 5554072,
#   'name': 'Juneau',
#   'cod': 200},
#  {'coord': {'lon': 81.82, 'lat': 7.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 301.16,
#    'feels_like': 302.29,
#    'temp_min': 301.16,
#    'temp_max': 301.16,
#    'pressure': 1013,
#    'humidity': 76,
#    'sea_level': 1013,
#    'grnd_level': 1013},
#   'wind': {'speed': 6.18, 'deg': 35},
#   'clouds': {'all': 2},
#   'dt': 1578278854,
#   'sys': {'country': 'LK', 'sunrise': 1578271606, 'sunset': 1578313752},
#   'timezone': 19800,
#   'id': 1242110,
#   'name': 'Kalmunai',
#   'cod': 200},
#  {'coord': {'lon': -72.03, 'lat': 42.08},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 271.52,
#    'feels_like': 262.65,
#    'temp_min': 269.82,
#    'temp_max': 273.15,
#    'pressure': 1010,
#    'humidity': 68},
#   'visibility': 16093,
#   'wind': {'speed': 8.7, 'deg': 280, 'gust': 12.9},
#   'clouds': {'all': 1},
#   'dt': 1578279197,
#   'sys': {'type': 1,
#    'id': 5231,
#    'country': 'US',
#    'sunrise': 1578226587,
#    'sunset': 1578259789},
#   'timezone': -18000,
#   'id': 4951594,
#   'name': 'Southbridge',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 249.92,
#    'feels_like': 244.79,
#    'temp_min': 249.92,
#    'temp_max': 249.92,
#    'pressure': 1023,
#    'humidity': 63,
#    'sea_level': 1023,
#    'grnd_level': 1021},
#   'wind': {'speed': 1.89, 'deg': 138},
#   'clouds': {'all': 1},
#   'dt': 1578278789,
#   'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': 72.61, 'lat': 61.09},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 270.15,
#    'feels_like': 264.27,
#    'temp_min': 270.15,
#    'temp_max': 270.15,
#    'pressure': 1008,
#    'humidity': 100},
#   'visibility': 10000,
#   'wind': {'speed': 5, 'deg': 220},
#   'clouds': {'all': 90},
#   'dt': 1578279197,
#   'sys': {'type': 1,
#    'id': 8987,
#    'country': 'RU',
#    'sunrise': 1578284355,
#    'sunset': 1578305425},
#   'timezone': 18000,
#   'id': 1497917,
#   'name': 'Nefteyugansk',
#   'cod': 200},
#  {'coord': {'lon': 155.8, 'lat': 62.53},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 252.27,
#    'feels_like': 248.23,
#    'temp_min': 252.27,
#    'temp_max': 252.27,
#    'pressure': 1023,
#    'humidity': 58,
#    'sea_level': 1023,
#    'grnd_level': 929},
#   'wind': {'speed': 0.38, 'deg': 352},
#   'clouds': {'all': 91},
#   'dt': 1578279197,
#   'sys': {'country': 'RU', 'sunrise': 1578265337, 'sunset': 1578284500},
#   'timezone': 39600,
#   'id': 2122493,
#   'name': 'Omsukchan',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 296.15,
#    'feels_like': 297.14,
#    'temp_min': 296.15,
#    'temp_max': 296.15,
#    'pressure': 1016,
#    'humidity': 55,
#    'sea_level': 1016,
#    'grnd_level': 960},
#   'wind': {'speed': 0.14, 'deg': 290},
#   'clouds': {'all': 82},
#   'dt': 1578278727,
#   'sys': {'country': 'AU', 'sunrise': 1578253383, 'sunset': 1578304712},
#   'timezone': 37800,
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 22.34, 'lat': 39.45},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 277.54,
#    'feels_like': 270.68,
#    'temp_min': 276.15,
#    'temp_max': 279.15,
#    'pressure': 1017,
#    'humidity': 41},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 330, 'gust': 10.8},
#   'clouds': {'all': 75},
#   'dt': 1578278742,
#   'sys': {'type': 1,
#    'id': 6629,
#    'country': 'GR',
#    'sunrise': 1578289861,
#    'sunset': 1578324056},
#   'timezone': 7200,
#   'id': 262462,
#   'name': 'Saint George',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 269.15,
#    'feels_like': 263.37,
#    'temp_min': 267.04,
#    'temp_max': 271.15,
#    'pressure': 1012,
#    'humidity': 73},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 280},
#   'clouds': {'all': 20},
#   'dt': 1578278706,
#   'sys': {'type': 1,
#    'id': 5414,
#    'country': 'US',
#    'sunrise': 1578227109,
#    'sunset': 1578260093},
#   'timezone': -18000,
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': 26.19, 'lat': 59.1},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 272.5,
#    'feels_like': 265.85,
#    'temp_min': 272.5,
#    'temp_max': 272.5,
#    'pressure': 1015,
#    'humidity': 95,
#    'sea_level': 1015,
#    'grnd_level': 1003},
#   'wind': {'speed': 6.4, 'deg': 209},
#   'snow': {'3h': 2.69},
#   'clouds': {'all': 100},
#   'dt': 1578278804,
#   'sys': {'country': 'EE', 'sunrise': 1578294416, 'sunset': 1578317652},
#   'timezone': 7200,
#   'id': 588365,
#   'name': 'Vao',
#   'cod': 200},
#  {'coord': {'lon': 118.35, 'lat': 63.29},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': 255.54,
#    'feels_like': 250.96,
#    'temp_min': 255.54,
#    'temp_max': 255.54,
#    'pressure': 1016,
#    'humidity': 98,
#    'sea_level': 1016,
#    'grnd_level': 999},
#   'wind': {'speed': 1.53, 'deg': 166},
#   'snow': {'3h': 0.13},
#   'clouds': {'all': 99},
#   'dt': 1578279198,
#   'sys': {'country': 'RU', 'sunrise': 1578274883, 'sunset': 1578292935},
#   'timezone': 32400,
#   'id': 2018735,
#   'name': 'Nyurba',
#   'cod': 200},
#  {'coord': {'lon': 99.39, 'lat': 55.1},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': 266.44,
#    'feels_like': 261.77,
#    'temp_min': 266.44,
#    'temp_max': 266.44,
#    'pressure': 1029,
#    'humidity': 84,
#    'sea_level': 1029,
#    'grnd_level': 964},
#   'wind': {'speed': 2.42, 'deg': 182},
#   'snow': {'3h': 0.19},
#   'clouds': {'all': 100},
#   'dt': 1578279198,
#   'sys': {'country': 'RU', 'sunrise': 1578275184, 'sunset': 1578301738},
#   'timezone': 28800,
#   'id': 1511276,
#   'name': 'Atagay',
#   'cod': 200},
#  {'coord': {'lon': 107.07, 'lat': -6.26},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 300.58,
#    'feels_like': 306.84,
#    'temp_min': 297.59,
#    'temp_max': 302.59,
#    'pressure': 1011,
#    'humidity': 94},
#   'visibility': 4000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1578279198,
#   'sys': {'type': 1,
#    'id': 9383,
#    'country': 'ID',
#    'sunrise': 1578264172,
#    'sunset': 1578309062},
#   'timezone': 25200,
#   'id': 1649378,
#   'name': 'Tambun',
#   'cod': 200},
#  {'coord': {'lon': 78.36, 'lat': 42.73},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 262.97,
#    'feels_like': 257.76,
#    'temp_min': 262.97,
#    'temp_max': 262.97,
#    'pressure': 1023,
#    'humidity': 37,
#    'sea_level': 1023,
#    'grnd_level': 785},
#   'wind': {'speed': 2.22, 'deg': 175},
#   'clouds': {'all': 62},
#   'dt': 1578279198,
#   'sys': {'country': 'KG', 'sunrise': 1578277016, 'sunset': 1578310004},
#   'timezone': 21600,
#   'id': 1527121,
#   'name': 'Tyup',
#   'cod': 200},
#  {'coord': {'lon': 47.99, 'lat': -14.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'model',
#   'main': {'temp': 297.09,
#    'feels_like': 301.47,
#    'temp_min': 297.09,
#    'temp_max': 297.09,
#    'pressure': 1011,
#    'humidity': 92,
#    'sea_level': 1011,
#    'grnd_level': 1003},
#   'wind': {'speed': 0.88, 'deg': 121},
#   'clouds': {'all': 12},
#   'dt': 1578279198,
#   'sys': {'country': 'MG', 'sunrise': 1578277454, 'sunset': 1578324148},
#   'timezone': 10800,
#   'id': 1068971,
#   'name': 'Antsohihy',
#   'cod': 200},
#  {'coord': {'lon': -124.02, 'lat': 54.02},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 268.62,
#    'feels_like': 262.97,
#    'temp_min': 268.62,
#    'temp_max': 268.62,
#    'pressure': 1015,
#    'humidity': 77,
#    'sea_level': 1015,
#    'grnd_level': 923},
#   'wind': {'speed': 3.94, 'deg': 221},
#   'clouds': {'all': 67},
#   'dt': 1578279198,
#   'sys': {'country': 'CA', 'sunrise': 1578242037, 'sunset': 1578269302},
#   'timezone': -28800,
#   'id': 6173361,
#   'name': 'Vanderhoof',
#   'cod': 200},
#  {'coord': {'lon': 103.39, 'lat': 1.48},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.03,
#    'feels_like': 305.02,
#    'temp_min': 301.48,
#    'temp_max': 302.15,
#    'pressure': 1013,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 360},
#   'clouds': {'all': 40},
#   'dt': 1578279199,
#   'sys': {'type': 1,
#    'id': 9480,
#    'country': 'MY',
#    'sunrise': 1578265833,
#    'sunset': 1578309169},
#   'timezone': 28800,
#   'id': 1732711,
#   'name': 'Pontian Kecil',
#   'cod': 200},
#  {'coord': {'lon': -7.17, 'lat': 62.16},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 282.15,
#    'feels_like': 275.84,
#    'temp_min': 282.15,
#    'temp_max': 282.15,
#    'pressure': 993,
#    'humidity': 100},
#   'visibility': 3700,
#   'wind': {'speed': 8.7, 'deg': 170, 'gust': 15.4},
#   'clouds': {'all': 100},
#   'dt': 1578279199,
#   'sys': {'type': 1,
#    'id': 1596,
#    'country': 'FO',
#    'sunrise': 1578304164,
#    'sunset': 1578323922},
#   'timezone': 0,
#   'id': 2610343,
#   'name': 'Vestmanna',
#   'cod': 200},
#  {'coord': {'lon': 143.24, 'lat': 64.57},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 242.56,
#    'feels_like': 238.07,
#    'temp_min': 242.56,
#    'temp_max': 242.56,
#    'pressure': 1029,
#    'humidity': 100,
#    'sea_level': 1029,
#    'grnd_level': 900},
#   'wind': {'speed': 0.92, 'deg': 228},
#   'clouds': {'all': 100},
#   'dt': 1578278847,
#   'sys': {'country': 'RU', 'sunrise': 1578270024, 'sunset': 1578285844},
#   'timezone': 36000,
#   'id': 2120048,
#   'name': 'Ust-Nera',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 290.12,
#    'feels_like': 289.05,
#    'temp_min': 289.82,
#    'temp_max': 290.37,
#    'pressure': 1009,
#    'humidity': 94},
#   'wind': {'speed': 4.37, 'deg': 225},
#   'clouds': {'all': 100},
#   'dt': 1578278794,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'country': 'ZA',
#    'sunrise': 1578281859,
#    'sunset': 1578333547},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 111.9, 'lat': -8.09},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 303.2,
#    'feels_like': 306.79,
#    'temp_min': 303.2,
#    'temp_max': 303.2,
#    'pressure': 1010,
#    'humidity': 66,
#    'sea_level': 1010,
#    'grnd_level': 990},
#   'wind': {'speed': 2.35, 'deg': 190},
#   'rain': {'3h': 0.75},
#   'clouds': {'all': 15},
#   'dt': 1578279199,
#   'sys': {'country': 'ID', 'sunrise': 1578262825, 'sunset': 1578308090},
#   'timezone': 25200,
#   'id': 1648082,
#   'name': 'Boyolangu',
#   'cod': 200},
#  {'coord': {'lon': -124.16, 'lat': 40.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 280.29,
#    'feels_like': 278.14,
#    'temp_min': 279.26,
#    'temp_max': 281.15,
#    'pressure': 1037,
#    'humidity': 87},
#   'visibility': 14484,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1578279199,
#   'sys': {'type': 1,
#    'id': 4127,
#    'country': 'US',
#    'sunrise': 1578238861,
#    'sunset': 1578272545},
#   'timezone': -28800,
#   'id': 5563397,
#   'name': 'Eureka',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 302.6,
#    'feels_like': 303.29,
#    'temp_min': 302.6,
#    'temp_max': 302.6,
#    'pressure': 1005,
#    'humidity': 75,
#    'sea_level': 1005,
#    'grnd_level': 1005},
#   'wind': {'speed': 7.79, 'deg': 95},
#   'rain': {'3h': 11.06},
#   'clouds': {'all': 100},
#   'dt': 1578278706,
#   'sys': {'country': 'KI', 'sunrise': 1578249331, 'sunset': 1578292349},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 135.86, 'lat': -34.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 293.18,
#    'feels_like': 290.14,
#    'temp_min': 293.18,
#    'temp_max': 293.18,
#    'pressure': 1018,
#    'humidity': 54,
#    'sea_level': 1018,
#    'grnd_level': 1012},
#   'wind': {'speed': 4.57, 'deg': 131},
#   'clouds': {'all': 2},
#   'dt': 1578279199,
#   'sys': {'country': 'AU', 'sunrise': 1578253807, 'sunset': 1578305604},
#   'timezone': 37800,
#   'id': 2063036,
#   'name': 'Port Lincoln',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 292.11,
#    'feels_like': 292.7,
#    'temp_min': 289.26,
#    'temp_max': 294.26,
#    'pressure': 1020,
#    'humidity': 77},
#   'visibility': 11265,
#   'wind': {'speed': 1.38, 'deg': 62},
#   'clouds': {'all': 75},
#   'dt': 1578278600,
#   'sys': {'type': 1,
#    'id': 7151,
#    'country': 'MX',
#    'sunrise': 1578232878,
#    'sunset': 1578271686},
#   'timezone': -25200,
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': -50.16, 'lat': -13.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 295.2,
#    'feels_like': 298.45,
#    'temp_min': 295.2,
#    'temp_max': 295.2,
#    'pressure': 1011,
#    'humidity': 98,
#    'sea_level': 1011,
#    'grnd_level': 981},
#   'wind': {'speed': 1.86, 'deg': 49},
#   'clouds': {'all': 73},
#   'dt': 1578278536,
#   'sys': {'country': 'BR', 'sunrise': 1578214758, 'sunset': 1578261118},
#   'timezone': -10800,
#   'id': 3448455,
#   'name': 'Sao Miguel do Araguaia',
#   'cod': 200},
#  {'coord': {'lon': 67.71, 'lat': 47.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 261.15,
#    'feels_like': 253.69,
#    'temp_min': 261.15,
#    'temp_max': 261.15,
#    'pressure': 1018,
#    'humidity': 92},
#   'visibility': 10000,
#   'wind': {'speed': 6, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1578278799,
#   'sys': {'type': 1,
#    'id': 8826,
#    'country': 'KZ',
#    'sunrise': 1578280659,
#    'sunset': 1578311474},
#   'timezone': 21600,
#   'id': 1516589,
#   'name': 'Zhezkazgan',
#   'cod': 200},
#  {'coord': {'lon': 159.59, 'lat': -8.15},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': 302.89,
#    'feels_like': 305.71,
#    'temp_min': 302.89,
#    'temp_max': 302.89,
#    'pressure': 1005,
#    'humidity': 70,
#    'sea_level': 1005,
#    'grnd_level': 996},
#   'wind': {'speed': 4.01, 'deg': 90},
#   'clouds': {'all': 47},
#   'dt': 1578278841,
#   'sys': {'country': 'SB', 'sunrise': 1578251369, 'sunset': 1578296648},
#   'timezone': 39600,
#   'id': 2109528,
#   'name': 'Buala',
#   'cod': 200},
#  {'coord': {'lon': 18.4, 'lat': 54.79},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 274.87,
#    'feels_like': 270.01,
#    'temp_min': 273.71,
#    'temp_max': 275.93,
#    'pressure': 1025,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1578279200,
#   'sys': {'type': 1,
#    'id': 1696,
#    'country': 'PL',
#    'sunrise': 1578294505,
#    'sunset': 1578321304},
#   'timezone': 3600,
#   'id': 3081752,
#   'name': 'Wladyslawowo',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 290.15,
#    'feels_like': 288.22,
#    'temp_min': 289.82,
#    'temp_max': 290.37,
#    'pressure': 1013,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 210},
#   'clouds': {'all': 40},
#   'dt': 1578278740,
#   'sys': {'type': 1,
#    'id': 1899,
#    'country': 'ZA',
#    'sunrise': 1578282132,
#    'sunset': 1578333667},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 123.94, 'lat': 10.29},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 302.15,
#    'feels_like': 304.85,
#    'temp_min': 302.15,
#    'temp_max': 302.15,
#    'pressure': 1013,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 40},
#   'clouds': {'all': 20},
#   'dt': 1578279200,
#   'sys': {'type': 1,
#    'id': 8187,
#    'country': 'PH',
#    'sunrise': 1578261787,
#    'sunset': 1578303347},
#   'timezone': 28800,
#   'id': 1717512,
#   'name': 'Canjulao',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 294.04,
#    'feels_like': 295.32,
#    'temp_min': 292.04,
#    'temp_max': 295.15,
#    'pressure': 1021,
#    'humidity': 83},
#   'visibility': 3219,
#   'wind': {'speed': 2.1, 'deg': 10},
#   'rain': {'1h': 2.03},
#   'clouds': {'all': 90},
#   'dt': 1578278767,
#   'sys': {'type': 1,
#    'id': 7881,
#    'country': 'US',
#    'sunrise': 1578243355,
#    'sunset': 1578282897},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': 100.22, 'lat': 64.27},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 261.87,
#    'feels_like': 256.61,
#    'temp_min': 261.87,
#    'temp_max': 261.87,
#    'pressure': 1010,
#    'humidity': 89,
#    'sea_level': 1010,
#    'grnd_level': 960},
#   'wind': {'speed': 2.88, 'deg': 195},
#   'clouds': {'all': 100},
#   'dt': 1578278732,
#   'sys': {'country': 'RU', 'sunrise': 1578280057, 'sunset': 1578296467},
#   'timezone': 25200,
#   'id': 2014833,
#   'name': 'Tura',
#   'cod': 200},
#  {'coord': {'lon': 83.21, 'lat': 53.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 261.15,
#    'feels_like': 254.98,
#    'temp_min': 261.15,
# ...
#   'timezone': -18000,
#   'id': 4957320,
#   'name': 'Bar Harbor',
#   'cod': 200},
#  {'coord': {'lon': 120.44, 'lat': 41.58},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': 272.38,
#    'feels_like': 268.27,
#    'temp_min': 272.38,
#    'temp_max': 272.38,
#    'pressure': 1026,
#    'humidity': 91,
#    'sea_level': 1026,
#    'grnd_level': 991},
#   'wind': {'speed': 2.64, 'deg': 206},
#   'snow': {'3h': 0.5},
#   'clouds': {'all': 100},
#   'dt': 1578279272,
#   'sys': {'country': 'CN', 'sunrise': 1578266699, 'sunset': 1578300116},
#   'timezone': 28800,
#   'id': 2038120,
#   'name': 'Chaoyang',
#   'cod': 200},
#  {'coord': {'lon': 153.24, 'lat': -28.95},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.49,
#    'feels_like': 301.32,
#    'temp_min': 299.15,
#    'temp_max': 305.15,
#    'pressure': 1015,
#    'humidity': 45},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 130},
#   'clouds': {'all': 40},
#   'dt': 1578278818,
#   'sys': {'type': 1,
#    'id': 9537,
#    'country': 'AU',
#    'sunrise': 1578250483,
#    'sunset': 1578300583},
#   'timezone': 39600,
#   'id': 2160063,
#   'name': 'Codrington',
#   'cod': 200},
#  {'coord': {'lon': 48.53, 'lat': -20.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 296.2,
#    'feels_like': 298.97,
#    'temp_min': 296.2,
#    'temp_max': 296.2,
#    'pressure': 1013,
#    'humidity': 91,
#    'sea_level': 1013,
#    'grnd_level': 1007},
#   'wind': {'speed': 2.39, 'deg': 223},
#   'clouds': {'all': 2},
#   'dt': 1578279272,
#   'sys': {'country': 'MG', 'sunrise': 1578276682, 'sunset': 1578324660},
#   'timezone': 10800,
#   'id': 1058080,
#   'name': 'Nosy Varika',
#   'cod': 200},
#  {'coord': {'lon': 12.48, 'lat': 41.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 277.14,
#    'feels_like': 273.38,
#    'temp_min': 273.15,
#    'temp_max': 280.37,
#    'pressure': 1028,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 120},
#   'clouds': {'all': 0},
#   'dt': 1578279156,
#   'sys': {'type': 1,
#    'id': 6792,
#    'country': 'IT',
#    'sunrise': 1578292666,
#    'sunset': 1578325985},
#   'timezone': 3600,
#   'id': 6539761,
#   'name': 'Rome',
#   'cod': 200},
#  {'coord': {'lon': 150.17, 'lat': 59.7},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'model',
#   'main': {'temp': 264.56,
#    'feels_like': 258.52,
#    'temp_min': 264.56,
#    'temp_max': 264.56,
#    'pressure': 1021,
#    'humidity': 66,
#    'sea_level': 1021,
#    'grnd_level': 1020},
#   'wind': {'speed': 3.91, 'deg': 334},
#   'clouds': {'all': 18},
#   'dt': 1578278812,
#   'sys': {'country': 'RU', 'sunrise': 1578264980, 'sunset': 1578287560},
#   'timezone': 39600,
#   'id': 2127060,
#   'name': 'Arman',
#   'cod': 200},
#  {'coord': {'lon': 130.27, 'lat': 45.29},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 264.09,
#    'feels_like': 259.93,
#    'temp_min': 264.09,
#    'temp_max': 264.09,
#    'pressure': 1032,
#    'humidity': 82,
#    'sea_level': 1032,
#    'grnd_level': 973},
#   'wind': {'speed': 1.42, 'deg': 178},
#   'clouds': {'all': 93},
#   'dt': 1578279272,
#   'sys': {'country': 'CN', 'sunrise': 1578265079, 'sunset': 1578297016},
#   'timezone': 28800,
#   'id': 2036066,
#   'name': 'Linkou',
#   'cod': 200},
#  {'coord': {'lon': 124.56, 'lat': 11.13},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 305.93,
#    'feels_like': 309.45,
#    'temp_min': 305.93,
#    'temp_max': 305.93,
#    'pressure': 1011,
#    'humidity': 58},
#   'wind': {'speed': 2.8, 'deg': 107},
#   'clouds': {'all': 65},
#   'dt': 1578279273,
#   'sys': {'type': 3,
#    'id': 2022220,
#    'country': 'PH',
#    'sunrise': 1578261725,
#    'sunset': 1578303112},
#   'timezone': 28800,
#   'id': 1697018,
#   'name': 'Pagsangahan',
#   'cod': 200},
#  {'coord': {'lon': -70.76, 'lat': -28.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 286.96,
#    'feels_like': 287.02,
#    'temp_min': 286.96,
#    'temp_max': 286.96,
#    'pressure': 1019,
#    'humidity': 86,
#    'sea_level': 1019,
#    'grnd_level': 958},
#   'wind': {'speed': 0.59, 'deg': 306},
#   'clouds': {'all': 0},
#   'dt': 1578279273,
#   'sys': {'country': 'CL', 'sunrise': 1578217877, 'sunset': 1578267889},
#   'timezone': -10800,
#   'id': 3868633,
#   'name': 'Vallenar',
#   'cod': 200},
#  {'coord': {'lon': 134.5, 'lat': 33.93},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 281.61,
#    'feels_like': 277.76,
#    'temp_min': 281.15,
#    'temp_max': 282.15,
#    'pressure': 1029,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 360},
#   'clouds': {'all': 40},
#   'dt': 1578278796,
#   'sys': {'type': 1,
#    'id': 8027,
#    'country': 'JP',
#    'sunrise': 1578262065,
#    'sunset': 1578297999},
#   'timezone': 32400,
#   'id': 1865309,
#   'name': 'Katsuura',
#   'cod': 200},
#  {'coord': {'lon': 77.04, 'lat': 28.58},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 288.03,
#    'feels_like': 288.28,
#    'temp_min': 285.15,
#    'temp_max': 289.82,
#    'pressure': 1018,
#    'humidity': 93},
#   'visibility': 900,
#   'wind': {'speed': 1.33, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1578279273,
#   'sys': {'type': 1,
#    'id': 9165,
#    'country': 'IN',
#    'sunrise': 1578275118,
#    'sunset': 1578312535},
#   'timezone': 19800,
#   'id': 1273294,
#   'name': 'Dwarka',
#   'cod': 200},
#  {'coord': {'lon': 109.09, 'lat': 29.63},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 280.31,
#    'feels_like': 278.38,
#    'temp_min': 280.31,
#    'temp_max': 280.31,
#    'pressure': 1015,
#    'humidity': 99,
#    'sea_level': 1015,
#    'grnd_level': 905},
#   'wind': {'speed': 1.76, 'deg': 119},
#   'rain': {'3h': 2},
#   'clouds': {'all': 100},
#   'dt': 1578279273,
#   'sys': {'country': 'CN', 'sunrise': 1578267563, 'sunset': 1578304702},
#   'timezone': 28800,
#   'id': 1784461,
#   'name': 'Shizilu',
#   'cod': 200},
#  {'coord': {'lon': -74.57, 'lat': 44.94},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 263.27,
#    'feels_like': 259.12,
#    'temp_min': 261.48,
#    'temp_max': 264.82,
#    'pressure': 1013,
#    'humidity': 92},
#   'visibility': 16093,
#   'wind': {'speed': 1.47, 'deg': 208},
#   'clouds': {'all': 75},
#   'dt': 1578279273,
#   'sys': {'type': 1,
#    'id': 5420,
#    'country': 'US',
#    'sunrise': 1578227769,
#    'sunset': 1578259826},
#   'timezone': -18000,
#   'id': 5928065,
#   'name': 'Bombay',
#   'cod': 200},
#  {'coord': {'lon': -105.59, 'lat': 41.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 269.56,
#    'feels_like': 261.92,
#    'temp_min': 267.04,
#    'temp_max': 271.15,
#    'pressure': 1018,
#    'humidity': 68},
#   'visibility': 16093,
#   'wind': {'speed': 6.7, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1578279274,
#   'sys': {'type': 1,
#    'id': 4663,
#    'country': 'US',
#    'sunrise': 1578234497,
#    'sunset': 1578267992},
#   'timezone': -25200,
#   'id': 5830062,
#   'name': 'Laramie',
#   'cod': 200},
#  {'coord': {'lon': 33.13, 'lat': 15.16},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 286.02,
#    'feels_like': 279.99,
#    'temp_min': 286.02,
#    'temp_max': 286.02,
#    'pressure': 1016,
#    'humidity': 24,
#    'sea_level': 1016,
#    'grnd_level': 970},
#   'wind': {'speed': 4.58, 'deg': 359},
#   'clouds': {'all': 0},
#   'dt': 1578279274,
#   'sys': {'country': 'SD', 'sunrise': 1578284095, 'sunset': 1578324641},
#   'timezone': 7200,
#   'id': 364071,
#   'name': 'Wad Rawah',
#   'cod': 200},
#  {'coord': {'lon': -75.25, 'lat': 45.6},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 262.34,
#    'feels_like': 258.86,
#    'temp_min': 260.15,
#    'temp_max': 263.71,
#    'pressure': 1014,
#    'humidity': 84},
#   'visibility': 24140,
#   'wind': {'speed': 0.32, 'deg': 259},
#   'clouds': {'all': 40},
#   'dt': 1578279274,
#   'sys': {'type': 1,
#    'id': 851,
#    'country': 'CA',
#    'sunrise': 1578228074,
#    'sunset': 1578259848},
#   'timezone': -18000,
#   'id': 6166224,
#   'name': 'Thurso',
#   'cod': 200},
#  {'coord': {'lon': 128.01, 'lat': 50.66},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 251.15,
#    'feels_like': 246.37,
#    'temp_min': 251.15,
#    'temp_max': 251.15,
#    'pressure': 1031,
#    'humidity': 69},
#   'visibility': 9000,
#   'wind': {'speed': 1.46, 'deg': 23},
#   'clouds': {'all': 100},
#   'dt': 1578279274,
#   'sys': {'type': 1,
#    'id': 8859,
#    'country': 'RU',
#    'sunrise': 1578266923,
#    'sunset': 1578296258},
#   'timezone': 32400,
#   'id': 2016170,
#   'name': 'Srednebelaya',
#   'cod': 200},
#  {'coord': {'lon': 147.99, 'lat': -37.88},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 286.48,
#    'feels_like': 285.61,
#    'temp_min': 286.48,
#    'temp_max': 286.48,
#    'pressure': 1016,
#    'humidity': 94},
#   'wind': {'speed': 2.3, 'deg': 316},
#   'rain': {'3h': 4.25},
#   'clouds': {'all': 100},
#   'dt': 1578279274,
#   'sys': {'type': 3,
#    'id': 2011895,
#    'country': 'AU',
#    'sunrise': 1578250368,
#    'sunset': 1578303219},
#   'timezone': 39600,
#   'id': 2160735,
#   'name': 'Lakes Entrance',
#   'cod': 200},
#  {'coord': {'lon': 34.38, 'lat': 40.17},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 271.5,
#    'feels_like': 267.37,
#    'temp_min': 271.5,
#    'temp_max': 271.5,
#    'pressure': 1016,
#    'humidity': 61,
#    'sea_level': 1016,
#    'grnd_level': 869},
#   'wind': {'speed': 1.74, 'deg': 102},
#   'clouds': {'all': 100},
#   'dt': 1578279274,
#   'sys': {'country': 'TR', 'sunrise': 1578287097, 'sunset': 1578321039},
#   'timezone': 10800,
#   'id': 739236,
#   'name': 'Sungurlu',
#   'cod': 200},
#  {'coord': {'lon': 87.7, 'lat': 23.66},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 288.15,
#    'feels_like': 287.5,
#    'temp_min': 288.15,
#    'temp_max': 288.15,
#    'pressure': 1022,
#    'humidity': 87},
#   'visibility': 600,
#   'wind': {'speed': 2.2, 'deg': 339},
#   'clouds': {'all': 0},
#   'dt': 1578279274,
#   'sys': {'type': 1,
#    'id': 9144,
#    'country': 'IN',
#    'sunrise': 1578271948,
#    'sunset': 1578310586},
#   'timezone': 19800,
#   'id': 1275346,
#   'name': 'Bolpur',
#   'cod': 200},
#  {'coord': {'lon': 163.07, 'lat': 59.24},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 259.9,
#    'feels_like': 254.88,
#    'temp_min': 259.9,
#    'temp_max': 259.9,
#    'pressure': 1019,
#    'humidity': 97,
#    'sea_level': 1019,
#    'grnd_level': 1017},
#   'wind': {'speed': 2.46, 'deg': 9},
#   'clouds': {'all': 100},
#   'dt': 1578279275,
#   'sys': {'country': 'RU', 'sunrise': 1578261652, 'sunset': 1578284695},
#   'timezone': 43200,
#   'id': 2122389,
#   'name': 'Ossora',
#   'cod': 200},
#  {'coord': {'lon': 14.28, 'lat': -22.12},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 290.37,
#    'feels_like': 291.5,
#    'temp_min': 290.37,
#    'temp_max': 290.37,
#    'pressure': 1012,
#    'humidity': 89},
#   'wind': {'speed': 0.89, 'deg': 38, 'gust': 2.24},
#   'clouds': {'all': 75},
#   'dt': 1578278866,
#   'sys': {'type': 3,
#    'id': 2012545,
#    'country': 'NA',
#    'sunrise': 1578284723,
#    'sunset': 1578333064},
#   'timezone': 7200,
#   'id': 3356832,
#   'name': 'Henties Bay',
#   'cod': 200},
#  {'coord': {'lon': -169.92, 'lat': -19.06},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.15,
#    'feels_like': 303.34,
#    'temp_min': 299.15,
#    'temp_max': 299.15,
#    'pressure': 1011,
#    'humidity': 100},
#   'wind': {'speed': 4.1, 'deg': 120},
#   'clouds': {'all': 3},
#   'dt': 1578279275,
#   'sys': {'type': 1,
#    'id': 7306,
#    'country': 'NU',
#    'sunrise': 1578242871,
#    'sunset': 1578290506},
#   'timezone': -39600,
#   'id': 4036284,
#   'name': 'Alofi',
#   'cod': 200},
#  {'coord': {'lon': -122.96, 'lat': 46.72},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 277.94,
#    'feels_like': 274.41,
#    'temp_min': 276.48,
#    'temp_max': 279.26,
#    'pressure': 1029,
#    'humidity': 93},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 190},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1578278998,
#   'sys': {'type': 1,
#    'id': 3647,
#    'country': 'US',
#    'sunrise': 1578239773,
#    'sunset': 1578271057},
#   'timezone': -28800,
#   'id': 5789683,
#   'name': 'Centralia',
#   'cod': 200},
#  {'coord': {'lon': 124.29, 'lat': 8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.37,
#    'feels_like': 302.85,
#    'temp_min': 300.37,
#    'temp_max': 300.37,
#    'pressure': 1011,
#    'humidity': 73},
#   'wind': {'speed': 3.13, 'deg': 333, 'gust': 4.92},
#   'clouds': {'all': 7},
#   'dt': 1578278782,
#   'sys': {'type': 3,
#    'id': 2007154,
#    'country': 'PH',
#    'sunrise': 1578261470,
#    'sunset': 1578303497},
#   'timezone': 28800,
#   'id': 1701054,
#   'name': 'Marawi',
#   'cod': 200},
#  {'coord': {'lon': 5.58, 'lat': 62.2},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 281,
#    'feels_like': 276.05,
#    'temp_min': 279.26,
#    'temp_max': 282.15,
#    'pressure': 1007,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 200},
#   'rain': {'3h': 3.25},
#   'clouds': {'all': 100},
#   'dt': 1578279275,
#   'sys': {'type': 1,
#    'id': 1602,
#    'country': 'NO',
#    'sunrise': 1578301134,
#    'sunset': 1578320831},
#   'timezone': 3600,
#   'id': 3148133,
#   'name': 'Larsnes',
#   'cod': 200},
#  {'coord': {'lon': -57.88, 'lat': -21.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 300.01,
#    'feels_like': 299.3,
#    'temp_min': 300.01,
#    'temp_max': 300.01,
#    'pressure': 1002,
#    'humidity': 40,
#    'sea_level': 1002,
#    'grnd_level': 992},
#   'wind': {'speed': 1.95, 'deg': 18},
#   'clouds': {'all': 0},
#   'dt': 1578279275,
#   'sys': {'country': 'BR', 'sunrise': 1578215660, 'sunset': 1578263921},
#   'timezone': -14400,
#   'id': 3452712,
#   'name': 'Porto Murtinho',
#   'cod': 200},
#  {'coord': {'lon': 21.39, 'lat': 50.93},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 270.12,
#    'feels_like': 267.24,
#    'temp_min': 267.59,
#    'temp_max': 272.59,
#    'pressure': 1032,
#    'humidity': 89},
#   'wind': {'speed': 0.45, 'deg': 217, 'gust': 1.79},
#   'clouds': {'all': 91},
#   'dt': 1578279276,
#   'sys': {'type': 3,
#    'id': 2011337,
#    'country': 'PL',
#    'sunrise': 1578292581,
#    'sunset': 1578321792},
#   'timezone': 3600,
#   'id': 762863,
#   'name': 'Ostrowiec Swietokrzyski',
#   'cod': 200}]

# %% [markdown]
# ## Convert Raw Data to DataFrame

# %%
cities_weather_data = [{
        'City': dict['name'],
        'Country': dict['sys']['country'],
        'Date': dict['dt'],
        'Latitude': dict['coord']['lat'],
        'Temperature(F)': dict['main']['temp_max'],
        'Humidity(%)': dict['main']['humidity'],
        'Cloudiness(%)': dict['clouds']['all'],
        'Wind Speed(mph)': dict['wind']['speed']
    } for dict in sample_cities]

df = pd.DataFrame(cities_weather_data)

# Convert Epoch Timestamp to Readable Date Format
df['Date'] = pd.to_datetime(df['Date'], unit='s').dt.date

df.to_csv("WeatherOfCities.csv", index=False)

df.head()
# Out:
#         City Country        Date  Latitude  Temperature(F)  Humidity(%)  \
# 0     Kegums      LV  2020-01-06     56.75          273.15           95
# 1      Vaini      IN  2020-01-06     15.34          293.15           88
# 2    Okhotsk      RU  2020-01-06     59.36          258.36           79
# 3  Busselton      AU  2020-01-06    -33.64          305.37           12
# 4   Souillac      FR  2020-01-06     45.60          275.15           93
#
#    Cloudiness(%)  Wind Speed(mph)
# 0             90             5.10
# 1             75             2.60
# 2              0             4.08
# 3             23             5.11
# 4              0             1.50

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
x = df['Latitude']
y = df['Temperature(F)']
plt.scatter(x, y, edgecolor='black')

plt.xlabel('Latitude')
plt.ylabel('Temperature(F)')
plt.title('City Latitude vs. Max Temperature(2020-01-05)', fontsize=14)
plt.xlim(-60, 90)
plt.ylim(220, max(y) + 10)
plt.grid(axis='both', linestyle='-')
plt.rcParams['figure.figsize'] = [6,6]
plt.savefig('Fig1 Lat vs Temperature Plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
x = df['Latitude']
y = df['Humidity(%)']
plt.scatter(x, y, edgecolor='black')

plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs. Humidity(2020-01-05)', fontsize=14)
plt.xlim(-60, max(x) + 5)
plt.ylim(0,max(y) + 5)
plt.grid(axis='both', linestyle='-')
plt.rcParams['figure.figsize'] = [6,6]
plt.savefig('Fig2 Lat vs Humidity Plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
x = df['Latitude']
y = df['Cloudiness(%)']
plt.scatter(x, y, edgecolor='black')

plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs. Cloudiness(2020-01-05)', fontsize=14)
plt.xlim(-60, max(x) + 5)
plt.ylim(-10,max(y) + 5)
plt.grid(axis='both', linestyle='-')
plt.rcParams['figure.figsize'] = [6,6]
plt.savefig('Fig3 Lat vs Cloudiness Plot.png')
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
x = df['Latitude']
y = df['Wind Speed(mph)']
plt.scatter(x, y, edgecolor='black')

plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('City Latitude vs. Wind Speed(2020-01-05)', fontsize=14)
plt.xlim(-60, 90)
plt.ylim(0, max(y) + 5)
plt.grid(axis='both', linestyle='-')
plt.rcParams['figure.figsize'] = [6,6]
plt.savefig('Fig4 Lat vs Wind Speed Plot.png')
plt.show()

# %% [markdown]
# ## First Observable Trend
# ### The Fig 1 (Lat vs Temperature Plot.png) illustrates a curvilinear relationship between the variable "Latitude" and the variable "Temperature".
# ### City temperature increases along with its latitude rising from -60 to -20, remains steady and peaks at around 300F with the latitude ranges of -20 and 20, then begins to decrease through the positive latitudes where cities start locating away from the latitude of 0, the Equator, higher latitude and lower temperature.

# %% [markdown]
# ## Second Observable Trend
# ### The Fig 2 (Lat vs Humidity Plot.png) indicates a weak association between the variable "Latitude" and the varible "Humidity".
# ### Furthermore, the correlation between city latitude and humidity is positive although the correlation is strongly affected by a few outliers.

# %% [markdown]
# ## Third Observation
# ### The Fig 3 (Lat vs Cloudiness Plot.png) shows that no relationship is demonstrated between the variables "City Latitude" and "Cloudiness".
#
# ### The Fig 4 (Lat vs Wind Speed Plot.png)  shows that no relationship exists between the variables "City Latitude" and "Wind Speed".
